# %% [markdown]
# <a href="https://colab.research.google.com/github/listyaaa/Simulation-for-Data-Science-with-R/blob/master/Tugas1_NissaListya.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
# Memuat Data
df = pd.read_csv('Data Mining/movie_sample_dataset.csv')
df.head(10)
# Out:
#     color      director_name  duration        gross  \
# 0   Color    Martin Scorsese       240  116866727.0
# 1   Color        Shane Black       195  408992272.0
# 2  color   Quentin Tarantino       187   54116191.0
# 3   Color   Kenneth Lonergan       186      46495.0
# 4   Color      Peter Jackson       186  258355354.0
# 5     NaN                NaN       183  330249062.0
# 6   Color      Peter Jackson       -50  303001229.0
# 7   Color        Edward Hall       180          NaN
# 8   Color        Joss Whedon       173  623279547.0
# 9   Color        Joss Whedon       173  623279547.0
#
#                                  genres                          movie_title  \
# 0          Biography|Comedy|Crime|Drama              The Wolf of Wall Street
# 1               Action|Adventure|Sci-Fi                           Iron Man 3
# 2  Crime|Drama|Mystery|Thriller|Western                    The Hateful Eight
# 3                                 Drama                             Margaret
# ...

# %%
# Memeriksa Data
df.dtypes
# Out:
# color                    object
# director_name            object
# duration                  int64
# gross                   float64
# genres                   object
# movie_title              object
# title_year                int64
# language                 object
# country                  object
# budget                  float64
# imdb_score              float64
# actors                   object
# movie_facebook_likes      int64
# dtype: object

# %%
# Memeriksa jumlah missing values di setiap kolom
print(df.isnull().sum())
# Out:
# color                   11
# director_name           11
# duration                 0
# gross                    8
# genres                   1
# movie_title              0
# title_year               0
# language                 0
# country                  0
# budget                   4
# imdb_score               0
# actors                   0
# movie_facebook_likes     0
# dtype: int64

# %%
import numpy as np

# %%
# Membersihkan Data
# Mengganti "N/A" dengan NaN
df.replace("N/A", np.nan, inplace=True)

# %%
# 1. Menghapus baris yang memiliki NaN di kolom 'gross' dan 'budget'
# Menampilkan jumlah nilai NaN sebelum penghapusan
print("Jumlah nilai NaN sebelum penghapusan:")
print(df.isnull().sum())
# Out:
# Jumlah nilai NaN sebelum penghapusan:
# color                   11
# director_name           11
# duration                 0
# gross                    8
# genres                   1
# movie_title              0
# title_year               0
# language                 0
# country                  0
# budget                   4
# imdb_score               0
# actors                   0
# movie_facebook_likes     0
# dtype: int64

# %%
# Menghapus baris yang memiliki NaN di kolom 'gross' dan 'budget'
df_cleaned = df.dropna(subset=['gross', 'budget']).copy()

# %%
# Menampilkan jumlah nilai NaN setelah penghapusan
print("\nJumlah nilai NaN setelah penghapusan:")
print(df_cleaned.isnull().sum())
# Out:
# Jumlah nilai NaN setelah penghapusan:
# color                   10
# director_name           10
# duration                 0
# gross                    0
# genres                   1
# movie_title              0
# title_year               0
# language                 0
# country                  0
# budget                   0
# imdb_score               0
# actors                   0
# movie_facebook_likes     0
# dtype: int64

# %%
# Menampilkan beberapa baris dari DataFrame yang sudah dibersihkan
print("\nMenampilkan 5 baris pertama dari DataFrame yang sudah dibersihkan:")
print(df_cleaned.head(10))
# Out:
# Menampilkan 5 baris pertama dari DataFrame yang sudah dibersihkan:
#      color      director_name  duration        gross  \
# 0    Color    Martin Scorsese       240  116866727.0
# 1    Color        Shane Black       195  408992272.0
# 2   color   Quentin Tarantino       187   54116191.0
# 3    Color   Kenneth Lonergan       186      46495.0
# 4    Color      Peter Jackson       186  258355354.0
# 5      NaN                NaN       183  330249062.0
# 6    Color      Peter Jackson       -50  303001229.0
# 8    Color        Joss Whedon       173  623279547.0
# 9    Color        Joss Whedon       173  623279547.0
# 10     NaN         Tom Tykwer       172   27098580.0
#
#                                   genres                          movie_title  \
# 0           Biography|Comedy|Crime|Drama              The Wolf of Wall Street
# 1                Action|Adventure|Sci-Fi                           Iron Man 3
# ...

# %%
# 2. Menangani kesalahan penulisan di kolom 'color'
# Mengganti variasi 'color' menjadi 'Color'
df_cleaned['color'] = df_cleaned['color'].replace({'color': 'Color', 'colour': 'Color'})

# Menangani kesalahan penulisan di kolom 'country' (contoh)
# Mengubah 'usa' menjadi 'USA' dan 'uk' menjadi 'UK'
df_cleaned['country'] = df_cleaned['country'].replace({'usa': 'USA', 'uk': 'UK'})

# Normalisasi teks untuk kolom yang diinginkan
df_cleaned['color'] = df_cleaned['color'].str.capitalize()  # Mengubah ke format Capitalized
df_cleaned['country'] = df_cleaned['country'].str.upper()  # Mengubah ke huruf kapital semua

# Menampilkan hasil akhir
print(df_cleaned.head(10))
# Out:
#      color      director_name  duration        gross  \
# 0    Color    Martin Scorsese       240  116866727.0
# 1    Color        Shane Black       195  408992272.0
# 2   Color   Quentin Tarantino       187   54116191.0
# 3    Color   Kenneth Lonergan       186      46495.0
# 4    Color      Peter Jackson       186  258355354.0
# 5      NaN                NaN       183  330249062.0
# 6    Color      Peter Jackson       -50  303001229.0
# 8    Color        Joss Whedon       173  623279547.0
# 9    Color        Joss Whedon       173  623279547.0
# 10     NaN         Tom Tykwer       172   27098580.0
#
#                                   genres                          movie_title  \
# 0           Biography|Comedy|Crime|Drama              The Wolf of Wall Street
# 1                Action|Adventure|Sci-Fi                           Iron Man 3
# 2   Crime|Drama|Mystery|Thriller|Western                    The Hateful Eight
# ...

# %%
# 3. Ubah atau hapus nilai-nilai yang tidak standar, seperti nilai negatif atau "N/A".
# Ubah semua nilai negatif di seluruh DataFrame menjadi NaN
# Ubah nilai negatif di kolom 'duration' menjadi NaN
df['duration'] = np.where(df['duration'] < 0, np.nan, df['duration'])

# Jika kamu ingin menghapus semua baris yang mengandung NaN setelah penggantian
df.dropna(inplace=True)

# Menampilkan hasil akhir
print("DataFrame setelah menghapus nilai negatif dan 'N/A':")
print(df.head(10))
# Out:
# DataFrame setelah menghapus nilai negatif dan 'N/A':
#      color      director_name  duration        gross  \
# 0    Color    Martin Scorsese     240.0  116866727.0
# 1    Color        Shane Black     195.0  408992272.0
# 2   color   Quentin Tarantino     187.0   54116191.0
# 3    Color   Kenneth Lonergan     186.0      46495.0
# 4    Color      Peter Jackson     186.0  258355354.0
# 8    Color        Joss Whedon     173.0  623279547.0
# 9    Color        Joss Whedon     173.0  623279547.0
# 11   Color               Null     158.0  102515793.0
# 13   Color  Christopher Nolan     169.0  187991439.0
# 14   Color       F. Gary Gray     167.0  161029270.0
#
#                                   genres                          movie_title  \
# 0           Biography|Comedy|Crime|Drama              The Wolf of Wall Street
# 1                Action|Adventure|Sci-Fi                           Iron Man 3
# 2   Crime|Drama|Mystery|Thriller|Western                    The Hateful Eight
# ...

# %%
# Transformasi Data
# 1. Mengubah tipe data kolom gross dan budget
df[["gross", "budget"]] = df[["gross",
"budget"]].astype(int)

# Menghapus baris dengan NaN yang mungkin muncul setelah konversi tipe data
df.dropna(subset=['budget', 'gross'], inplace=True)

# Menampilkan hasil akhir
print("DataFrame setelah mengubah tipe data 'budget' dan 'gross':")
print(df.head())
# Out:
# DataFrame setelah mengubah tipe data 'budget' dan 'gross':
#     color      director_name  duration      gross  \
# 0   Color    Martin Scorsese     240.0  116866727
# 1   Color        Shane Black     195.0  408992272
# 2  color   Quentin Tarantino     187.0   54116191
# 3   Color   Kenneth Lonergan     186.0      46495
# 4   Color      Peter Jackson     186.0  258355354
#
#                                  genres                          movie_title  \
# 0          Biography|Comedy|Crime|Drama              The Wolf of Wall Street
# 1               Action|Adventure|Sci-Fi                           Iron Man 3
# 2  Crime|Drama|Mystery|Thriller|Western                    The Hateful Eight
# 3                                 Drama                             Margaret
# 4                     Adventure|Fantasy  The Hobbit: The Desolation of Smaug
#
#    title_year language country     budget  imdb_score  \
# 0        2013  English     USA  100000000         8.2
# ...

# %%
# 1. Mengubah tipe data kolom 'budget' dan 'gross' menjadi numerik
# Gunakan pd.to_numeric() untuk mengonversi dan atasi error jika ada nilai yang tidak bisa dikonversi
df['budget'] = pd.to_numeric(df['budget'], errors='coerce')
df['gross'] = pd.to_numeric(df['gross'], errors='coerce')

# Menghapus baris dengan NaN yang mungkin muncul setelah konversi tipe data
df.dropna(subset=['budget', 'gross'], inplace=True)

# 2. Memisahkan kolom 'genre' yang memiliki beberapa nilai dalam satu baris
# Misalkan nilai-nilai dalam kolom 'genre' dipisahkan dengan koma
df_genres = df['genres'].str.split(',', expand=True)

# Gabungkan kembali ke DataFrame asli (opsional)
# Ini akan menambahkan kolom-kolom baru sesuai dengan jumlah genre yang ditemukan
df = pd.concat([df, df_genres], axis=1)

print("Menampilkan 5 baris pertama dari DataFrame:")
print(df.head())  # Menampilkan 5 baris pertama
# Out:
# Menampilkan 5 baris pertama dari DataFrame:
#     color      director_name  duration        gross  \
# 0   Color    Martin Scorsese       240  116866727.0
# 1   Color        Shane Black       195  408992272.0
# 2  color   Quentin Tarantino       187   54116191.0
# 3   Color   Kenneth Lonergan       186      46495.0
# 4   Color      Peter Jackson       186  258355354.0
#
#                                  genres                          movie_title  \
# 0          biography|comedy|crime|drama              The Wolf of Wall Street
# 1               action|adventure|sci-fi                           Iron Man 3
# 2  crime|drama|mystery|thriller|western                    The Hateful Eight
# 3                                 drama                             Margaret
# 4                     adventure|fantasy  The Hobbit: The Desolation of Smaug
#
#    title_year language country       budget  imdb_score  \
# 0        2013  English     usa  100000000.0         8.2
# ...

# %%
# Menyimpan Data
df.to_csv('movie_dataset_cleaned.csv', index=False)

# %%
df = pd.read_csv('movie_dataset_cleaned.csv')
df.head(10)
# Out:
#     color      director_name  duration      gross  \
# 0   Color    Martin Scorsese     240.0  116866727
# 1   Color        Shane Black     195.0  408992272
# 2  color   Quentin Tarantino     187.0   54116191
# 3   Color   Kenneth Lonergan     186.0      46495
# 4   Color      Peter Jackson     186.0  258355354
# 5   Color        Joss Whedon     173.0  623279547
# 6   Color        Joss Whedon     173.0  623279547
# 7   Color               Null     158.0  102515793
# 8   Color  Christopher Nolan     169.0  187991439
# 9   Color       F. Gary Gray     167.0  161029270
#
#                                  genres                          movie_title  \
# 0          Biography|Comedy|Crime|Drama              The Wolf of Wall Street
# 1               Action|Adventure|Sci-Fi                           Iron Man 3
# 2  Crime|Drama|Mystery|Thriller|Western                    The Hateful Eight
# 3                                 Drama                             Margaret
# ...
